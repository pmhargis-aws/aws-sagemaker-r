# %% [markdown]
# ### Test Notebook to validate that the CustomR environment contains our dependencies
#
# We start this notebook using the kernel named "conda_r_custom_r". We launch this kernel from the Jupyter UI on the Files tab by selecting "New->" pulldown and selecting the kernel by name.

# %%
print(paste("This is R kernel:","conda_r_custom_r"))
# Out:
# [1] "This is R kernel: conda_r_custom_r"

# %%
library(reticulate)

# %%
installed.packages()
# Out:
#             Package     LibPath
# arules      arules      /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# askpass     askpass     /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# assertthat  assertthat  /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# backports   backports   /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# base        base        /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# base64enc   base64enc   /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# BH          BH          /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# bit         bit         /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# bit64       bit64       /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# bitops      bitops      /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# boot        boot        /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# broom       broom       /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# callr       callr       /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# caret       caret       /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# catboost    catboost    /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# caTools     caTools     /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# cellranger  cellranger  /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# class       class       /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# cli         cli         /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# clipr       clipr       /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# cluster     cluster     /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# codetools   codetools   /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# colorspace  colorspace  /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# combinat    combinat    /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# compiler    compiler    /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# crayon      crayon      /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# curl        curl        /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# data.table  data.table  /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# datasets    datasets    /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# DBI         DBI         /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# ...         ...         ...
# sys         sys         /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# tcltk       tcltk       /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# testthat    testthat    /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# tibble      tibble      /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# tictoc      tictoc      /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# tidyr       tidyr       /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# tidyselect  tidyselect  /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# tidyverse   tidyverse   /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# timeDate    timeDate    /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# timeSeries  timeSeries  /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# tinytex     tinytex     /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# tools       tools       /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# tseries     tseries     /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# tsoutliers  tsoutliers  /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# TTR         TTR         /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# urca        urca        /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# utf8        utf8        /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# utils       utils       /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# uuid        uuid        /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# viridisLite viridisLite /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# whisker     whisker     /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# withr       withr       /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# wordcloud   wordcloud   /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# xfun        xfun        /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# xgboost     xgboost     /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# xml2        xml2        /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# xtable      xtable      /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# xts         xts         /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# yaml        yaml        /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
# zoo         zoo         /home/ec2-user/SageMaker/envs/custom-r/lib/R/library
#             Version  Priority
# arules      1.6-6    NA
# askpass     1.0      NA
# assertthat  0.2.1    NA
# backports   1.1.4    NA
# base        3.6.1    base
# base64enc   0.1-3    NA
# BH          1.69.0-1 NA
# bit         1.1-15.2 NA
# bit64       0.9-7.1  NA
# bitops      1.0-6    NA
# boot        1.3-20   recommended
# broom       0.5.2    NA
# callr       3.2.0    NA
# caret       6.0-83   NA
# catboost    0.23.2   NA
# caTools     1.18.0   NA
# cellranger  1.1.0    NA
# class       7.3-15   NA
# cli         1.1.0    NA
# clipr       0.6.0    NA
# cluster     2.0.8    NA
# codetools   0.2-16   recommended
# colorspace  1.4-1    NA
# combinat    0.0-8    NA
# compiler    3.6.1    base
# crayon      1.3.4    NA
# curl        3.3      NA
# data.table  1.12.2   NA
# datasets    3.6.1    base
# DBI         1.0.0    NA
# ...         ...      ...
# sys         3.2      NA
# tcltk       3.6.1    base
# testthat    2.3.2    NA
# tibble      2.1.1    NA
# tictoc      1.0      NA
# tidyr       0.8.3    NA
# tidyselect  0.2.5    NA
# tidyverse   1.2.1    NA
# timeDate    3043.102 NA
# timeSeries  3062.100 NA
# tinytex     0.12     NA
# tools       3.6.1    base
# tseries     0.10-47  NA
# tsoutliers  0.6-8    NA
# TTR         0.23-4   NA
# urca        1.3-0    NA
# utf8        1.1.4    NA
# utils       3.6.1    base
# uuid        0.1-2    NA
# viridisLite 0.3.0    NA
# whisker     0.3-2    NA
# withr       2.1.2    NA
# wordcloud   2.6      NA
# xfun        0.6      NA
# xgboost     1.1.1.1  NA
# xml2        1.2.0    NA
# xtable      1.8-4    NA
# xts         0.11-2   NA
# yaml        2.2.0    NA
# zoo         1.8-6    NA
#             Depends
# arules      R (>= 3.4.0), Matrix (>= 1.2-0)
# askpass     NA
# assertthat  NA
# backports   R (>= 3.0.0)
# base        NA
# base64enc   R (>= 2.9.0)
# BH          NA
# bit         R (>= 2.9.2)
# bit64       R (>= 3.0.1), bit (>= 1.1-12), utils, methods, stats
# bitops      NA
# boot        R (>= 3.0.0), graphics, stats
# broom       R (>= 3.1)
# callr       NA
# caret       R (>= 3.5.0), lattice (>= 0.20), ggplot2
# catboost    NA
# caTools     R (>= 3.6.0)
# cellranger  R (>= 3.0.0)
# class       R (>= 3.0.0), stats, utils
# cli         R (>= 2.10)
# clipr       NA
# cluster     R (>= 3.3.0)
# codetools   R (>= 2.1)
# colorspace  R (>= 3.0.0), methods
# combinat    NA
# compiler    NA
# crayon      NA
# curl        R (>= 3.0.0)
# data.table  R (>= 3.1.0)
# datasets    NA
# DBI         R (>= 3.0.0), methods
# ...         ...
# sys         NA
# tcltk       NA
# testthat    R (>= 3.1)
# tibble      R (>= 3.1.0)
# tictoc      R (>= 3.0.3), methods
# tidyr       R (>= 3.1)
# tidyselect  R (>= 3.1)
# tidyverse   NA
# timeDate    R (>= 2.15.1), graphics, utils, stats, methods
# timeSeries  R (>= 2.10), graphics, grDevices, stats, methods, utils,\ntimeDate (>= 2150.95)
# tinytex     NA
# tools       NA
# tseries     R (>= 2.10.0)
# tsoutliers  R (>= 3.0.0)
# TTR         NA
# urca        R (>= 2.0.0), methods
# utf8        R (>= 2.10)
# utils       NA
# uuid        R (>= 2.9.0)
# viridisLite R (>= 2.10)
# whisker     NA
# withr       R (>= 3.0.2)
# wordcloud   methods, RColorBrewer
# xfun        NA
# xgboost     R (>= 3.3.0)
# xml2        R (>= 3.1.0)
# xtable      R (>= 2.10.0)
# xts         zoo (>= 1.7-12)
# yaml        NA
# zoo         R (>= 3.1.0), stats
#             Imports
# arules      stats, methods, graphics, utils
# askpass     sys (>= 2.1)
# assertthat  tools
# backports   utils
# base        NA
# base64enc   NA
# BH          NA
# bit         NA
# bit64       NA
# bitops      NA
# boot        NA
# broom       backports, dplyr, generics (>= 0.0.2), methods, nlme, purrr,\nreshape2, stringr, tibble, tidyr
# callr       processx (>= 3.3.0), R6, utils
# caret       foreach, methods, plyr, ModelMetrics (>= 1.1.0), nlme,\nreshape2, stats, stats4, utils, grDevices, recipes (>= 0.1.4),\nwithr (>= 2.0.0)
# catboost    jsonlite
# caTools     bitops
# cellranger  rematch, tibble
# class       MASS
# cli         assertthat, crayon (>= 1.3.4), methods, utils
# clipr       utils
# cluster     graphics, grDevices, stats, utils
# codetools   NA
# colorspace  graphics, grDevices, stats
# combinat    NA
# compiler    NA
# crayon      grDevices, methods, utils
# curl        NA
# data.table  methods
# datasets    NA
# DBI         NA
# ...         ...
# sys         NA
# tcltk       utils
# testthat    cli, crayon (>= 1.3.4), digest, ellipsis, evaluate, magrittr,\nmethods, pkgload, praise, R6 (>= 2.2.0), rlang (>= 0.4.1),\nwithr (>= 2.0.0)
# tibble      cli (>= 1.0.1), crayon (>= 1.3.4), fansi (>= 0.4.0), methods,\npillar (>= 1.3.1), pkgconfig (>= 2.0.2), rlang (>= 0.3.1),\nutils
# tictoc      NA
# tidyr       dplyr (>= 0.7.0), glue, magrittr, purrr, Rcpp, rlang, stringi,\ntibble, tidyselect (>= 0.2.5), utils
# tidyselect  glue (>= 1.3.0), purrr, rlang (>= 0.2.2), Rcpp (>= 0.12.0)
# tidyverse   broom (>= 0.4.2), cli (>= 1.0.0), crayon (>= 1.3.4), dplyr (>=\n0.7.4), dbplyr (>= 1.1.0), forcats (>= 0.2.0), ggplot2 (>=\n2.2.1), haven (>= 1.1.0), hms (>= 0.3), httr (>= 1.3.1),\njsonlite (>= 1.5), lubridate (>= 1.7.1), magrittr (>= 1.5),\nmodelr (>= 0.1.1), purrr (>= 0.2.4), readr (>= 1.1.1), readxl\n(>= 1.0.0), reprex (>= 0.1.1), rlang (>= 0.1.4), rstudioapi (>=\n0.7), rvest (>= 0.3.2), stringr (>= 1.2.0), tibble (>= 1.3.4),\ntidyr (>= 0.7.2), xml2 (>= 1.1.1)
# timeDate    NA
# timeSeries  NA
# tinytex     xfun (>= 0.5)
# tools       NA
# tseries     graphics, stats, utils, quadprog, zoo, quantmod (>= 0.4-9)
# tsoutliers  forecast, stats
# TTR         xts (>= 0.10-0), zoo, curl
# urca        nlme, graphics, stats
# utf8        NA
# utils       NA
# uuid        NA
# viridisLite NA
# whisker     NA
# withr       stats, graphics, grDevices
# wordcloud   Rcpp (>= 0.9.4)
# xfun        tools
# xgboost     Matrix (>= 1.1-0), methods, data.table (>= 1.9.6), magrittr\n(>= 1.5), stringi (>= 0.5.2)
# xml2        Rcpp
# xtable      stats, utils
# xts         methods
# yaml        NA
# zoo         utils, graphics, grDevices, lattice (>= 0.20-27)
#             LinkingTo
# arules      NA
# askpass     NA
# assertthat  NA
# backports   NA
# base        NA
# base64enc   NA
# BH          NA
# bit         NA
# bit64       NA
# bitops      NA
# boot        NA
# broom       NA
# callr       NA
# caret       NA
# catboost    NA
# caTools     NA
# cellranger  NA
# class       NA
# cli         NA
# clipr       NA
# cluster     NA
# codetools   NA
# colorspace  NA
# combinat    NA
# compiler    NA
# crayon      NA
# curl        NA
# data.table  NA
# datasets    NA
# DBI         NA
# ...         ...
# sys         NA
# tcltk       NA
# testthat    NA
# tibble      NA
# tictoc      NA
# tidyr       Rcpp
# tidyselect  Rcpp (>= 0.12.0),
# tidyverse   NA
# timeDate    NA
# timeSeries  NA
# tinytex     NA
# tools       NA
# tseries     NA
# tsoutliers  NA
# TTR         xts
# urca        NA
# utf8        NA
# utils       NA
# uuid        NA
# viridisLite NA
# whisker     NA
# withr       NA
# wordcloud   Rcpp
# xfun        NA
# xgboost     NA
# xml2        Rcpp (>= 0.12.12)
# xtable      NA
# xts         zoo
# yaml        NA
# zoo         NA
#             Suggests
# arules      pmml, XML, arulesViz, testthat
# askpass     testthat
# assertthat  testthat, covr
# backports   NA
# base        methods
# ...
# viridisLite hexbin (>= 1.27.0), ggplot2 (>= 1.0.1), testthat, covr
# whisker     markdown
# withr       testthat, covr, lattice, DBI, RSQLite, methods, knitr,\nrmarkdown
# wordcloud   tm (>= 0.6), slam
# xfun        testit, parallel, rstudioapi, tinytex, mime, markdown, knitr,\nhtmltools, base64enc, remotes, rmarkdown
# xgboost     knitr, rmarkdown, ggplot2 (>= 1.0.1), DiagrammeR (>= 0.9.0),\nCkmeans.1d.dp (>= 3.3.1), vcd (>= 1.3), testthat, lintr, igraph\n(>= 1.0.1), jsonlite, float
# xml2        testthat, curl, covr, knitr, rmarkdown, magrittr, httr
# xtable      knitr, plm, zoo, survival
# xts         timeSeries, timeDate, tseries, chron, fts, tis, RUnit
# yaml        RUnit
# zoo         coda, chron, DAAG, fts, ggplot2, mondate, scales,\nstrucchange, timeDate, timeSeries, tis, tseries, xts
#             Enhances License                                License_is_FOSS
# arules      NA       GPL-3                                  NA
# askpass     NA       MIT + file LICENSE                     NA
# assertthat  NA       GPL-3                                  NA
# backports   NA       GPL-2                                  NA
# base        NA       Part of R 3.6.1                        NA
# base64enc   png      GPL-2 | GPL-3                          NA
# BH          NA       BSL-1.0                                NA
# bit         NA       GPL-2                                  NA
# bit64       NA       GPL-2                                  NA
# bitops      NA       GPL (>= 2)                             NA
# boot        NA       Unlimited                              NA
# broom       NA       MIT + file LICENSE                     NA
# callr       NA       MIT + file LICENSE                     NA
# caret       NA       GPL (>= 2)                             NA
# catboost    NA       Apache License (== 2.0)                NA
# caTools     NA       GPL-3                                  NA
# cellranger  NA       MIT + file LICENSE                     NA
# class       NA       GPL-2 | GPL-3                          NA
# cli         NA       MIT + file LICENSE                     NA
# clipr       NA       GPL-3                                  NA
# cluster     NA       GPL (>= 2)                             NA
# codetools   NA       GPL                                    NA
# colorspace  NA       BSD_3_clause + file LICENSE            NA
# combinat    NA       GPL-2                                  NA
# compiler    NA       Part of R 3.6.1                        NA
# crayon      NA       MIT + file LICENSE                     NA
# curl        NA       MIT + file LICENSE                     NA
# data.table  NA       MPL-2.0 | file LICENSE                 NA
# datasets    NA       Part of R 3.6.1                        NA
# DBI         NA       LGPL (>= 2)                            NA
# ...         ...      ...                                    ...
# sys         NA       MIT + file LICENSE                     NA
# tcltk       NA       Part of R 3.6.1                        NA
# testthat    NA       MIT + file LICENSE                     NA
# tibble      NA       MIT + file LICENSE                     NA
# tictoc      NA       Apache License (== 2.0) | file LICENSE NA
# tidyr       NA       MIT + file LICENSE                     NA
# tidyselect  NA       GPL-3                                  NA
# tidyverse   NA       GPL-3 | file LICENSE                   NA
# timeDate    NA       GPL (>= 2)                             NA
# timeSeries  NA       GPL (>= 2)                             NA
# tinytex     NA       MIT + file LICENSE                     NA
# tools       NA       Part of R 3.6.1                        NA
# tseries     NA       GPL-2                                  NA
# tsoutliers  NA       GPL-2                                  NA
# TTR         quantmod GPL-2                                  NA
# urca        NA       GPL (>= 2)                             NA
# utf8        NA       Apache License (== 2.0) | file LICENSE NA
# utils       NA       Part of R 3.6.1                        NA
# uuid        NA       MIT + file LICENSE                     NA
# viridisLite NA       MIT + file LICENSE                     NA
# whisker     NA       GPL-3                                  NA
# withr       NA       GPL (>= 2)                             NA
# wordcloud   NA       LGPL-2.1                               NA
# xfun        NA       MIT + file LICENSE                     NA
# xgboost     NA       Apache License (== 2.0) | file LICENSE NA
# xml2        NA       GPL (>= 2)                             NA
# xtable      NA       GPL (>= 2)                             NA
# xts         NA       GPL (>= 2)                             NA
# yaml        NA       BSD_3_clause + file LICENSE            NA
# zoo         NA       GPL-2 | GPL-3                          NA
#             License_restricts_use OS_type MD5sum NeedsCompilation Built
# arules      NA                    NA      NA     yes              3.6.1
# askpass     NA                    NA      NA     yes              3.6.0
# assertthat  NA                    NA      NA     no               3.6.0
# backports   NA                    NA      NA     yes              3.6.0
# base        NA                    NA      NA     NA               3.6.1
# base64enc   NA                    NA      NA     yes              3.6.0
# BH          NA                    NA      NA     no               3.6.0
# bit         NA                    NA      NA     yes              3.6.1
# bit64       NA                    NA      NA     yes              3.6.1
# bitops      NA                    NA      NA     yes              3.6.1
# boot        NA                    NA      NA     no               3.6.0
# broom       NA                    NA      NA     no               3.6.0
# callr       NA                    NA      NA     no               3.6.0
# caret       NA                    NA      NA     yes              3.6.0
# catboost    NA                    NA      NA     yes              3.6.1
# caTools     NA                    NA      NA     yes              3.6.1
# cellranger  NA                    NA      NA     no               3.6.0
# class       NA                    NA      NA     yes              3.6.0
# cli         NA                    NA      NA     no               3.6.0
# clipr       NA                    NA      NA     no               3.6.0
# cluster     NA                    NA      NA     yes              3.6.0
# codetools   NA                    NA      NA     no               3.6.0
# colorspace  NA                    NA      NA     yes              3.6.0
# combinat    NA                    NA      NA     NA               3.6.1
# compiler    NA                    NA      NA     NA               3.6.1
# crayon      NA                    NA      NA     no               3.6.0
# curl        NA                    NA      NA     yes              3.6.0
# data.table  NA                    NA      NA     yes              3.6.0
# datasets    NA                    NA      NA     NA               3.6.1
# DBI         NA                    NA      NA     no               3.6.0
# ...         ...                   ...     ...    ...              ...
# sys         NA                    NA      NA     yes              3.6.0
# tcltk       NA                    NA      NA     yes              3.6.1
# testthat    NA                    NA      NA     yes              3.6.1
# tibble      NA                    NA      NA     yes              3.6.0
# tictoc      NA                    NA      NA     no               3.6.1
# tidyr       NA                    NA      NA     yes              3.6.0
# tidyselect  NA                    NA      NA     yes              3.6.0
# tidyverse   NA                    NA      NA     no               3.6.0
# timeDate    NA                    NA      NA     no               3.6.0
# timeSeries  NA                    NA      NA     no               3.6.1
# tinytex     NA                    NA      NA     no               3.6.0
# tools       NA                    NA      NA     yes              3.6.1
# tseries     NA                    NA      NA     yes              3.6.1
# tsoutliers  NA                    NA      NA     no               3.6.1
# TTR         NA                    NA      NA     yes              3.6.0
# urca        NA                    NA      NA     yes              3.6.1
# utf8        NA                    NA      NA     yes              3.6.0
# utils       NA                    NA      NA     yes              3.6.1
# uuid        NA                    NA      NA     yes              3.6.0
# viridisLite NA                    NA      NA     no               3.6.0
# whisker     NA                    NA      NA     no               3.6.0
# withr       NA                    NA      NA     no               3.6.0
# wordcloud   NA                    NA      NA     yes              3.6.1
# xfun        NA                    NA      NA     no               3.6.0
# xgboost     NA                    NA      NA     yes              3.6.1
# xml2        NA                    NA      NA     yes              3.6.0
# xtable      NA                    NA      NA     no               3.6.0
# xts         NA                    NA      NA     yes              3.6.0
# yaml        NA                    NA      NA     yes              3.6.0
# zoo         NA                    NA      NA     yes              3.6.1

# %%
library(fpp)
library(lubridate)
library(RemixAutoML)
# Out:
# Loading required package: forecast
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'xts':
#   method     from
#   as.zoo.xts zoo
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
# Loading required package: fma
# Loading required package: expsmooth
# Loading required package: lmtest
# Loading required package: zoo
#
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
# Loading required package: tseries
#
# Attaching package: ‘lubridate’
#
# The following object is masked from ‘package:base’:
#
#     date

# %%
library(ggplot2)

# %%
data(a10)
autoplot(a10) +
  ggtitle("Antidiabetic drug sales") +
  ylab("$ million") +
  xlab("Year")
# Out:
# plot without title
